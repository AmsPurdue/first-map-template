# %%
# import python libraries 
# this is a comment and different than header because we are in the codespace

import pandas as pd # to work with tabular data (csv for ex)
import holoviews as hv # used to create interactive plots
import osmnx as osm # open street maps

# %%
# Search for boundary using OSM
# looking for the item in osm that is item 46226108 (unique identifier for CU boulder campus)
# searched by OSM id
# create a variable name called cu_boundary that contains the info on the right
cu_boundary = osm.geocode_to_gdf(

                        "W46226108",

                        by_osmid=True

)
cu_boundary
# the spatial data (nodes of the polygon) are stored in geometry colum
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-105.27660 40.01029, -105.27660 40.0...   40.013632   40.000279
#
#     bbox_east   bbox_west   place_id osm_type    osm_id        lat  \
# 0 -105.258821 -105.276605  329311639      way  46226108  40.007006
#
#           lon    class        type  place_rank  importance addresstype  \
# 0 -105.266442  amenity  university          30    0.583709     amenity
#
#                                            name  \
# 0  University of Colorado Boulder (Main Campus)
#
#                                         display_name
# 0  University of Colorado Boulder (Main Campus), ...

# %%
# 
cu_boundary.plot()
# Out:
# <Axes: >
